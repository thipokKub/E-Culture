# %%
import pandas as pd

# %%
dataset = pd.read_csv('ภาคเหนือ_part1.csv')
dataset2 = pd.read_csv('ภาคเหนือ_part2.csv')
dataset3 = pd.read_csv('ภาคเหนือ_part3.csv')
dataset = dataset.append(dataset2)
dataset = dataset.append(dataset3)

# %%
map_media = pd.read_csv('north_media.csv')

# %%
map_media[map_media['id'] == 'MOC-129129']
# Out:
#               id                                          thumb_pic  \
# 6425  MOC-129129  http://123.242.145.13/uploads/image/small_thum...
# 6426  MOC-129129  http://123.242.145.13/uploads/image/small_thum...
# 6427  MOC-129129  http://123.242.145.13/uploads/image/small_thum...
# 6428  MOC-129129  http://123.242.145.13/uploads/image/small_thum...
# 6429  MOC-129129  http://123.242.145.13/uploads/image/small_thum...
#
#                                      big_pic thumb_vdo big_vdo   type
# 6425  http://123.242.145.13/media/big/265434       NaN     NaN  image
# 6426  http://123.242.145.13/media/big/265433       NaN     NaN  image
# 6427  http://123.242.145.13/media/big/265432       NaN     NaN  image
# 6428  http://123.242.145.13/media/big/298851       NaN     NaN  image
# 6429  http://123.242.145.13/media/big/298852       NaN     NaN  image

# %%
dataset.head()
# Out:
#            id                      source                                 url  \
# 0  MOC-129129  ศูนย์ข้อมูลกลางทางวัฒนธรรม  http://123.242.145.13/album/129129
# 1  MOC-129118  ศูนย์ข้อมูลกลางทางวัฒนธรรม  http://123.242.145.13/album/129118
# 2  MOC-161355  ศูนย์ข้อมูลกลางทางวัฒนธรรม  http://123.242.145.13/album/161355
# 3  MOC-124225  ศูนย์ข้อมูลกลางทางวัฒนธรรม  http://123.242.145.13/album/124225
# 4  MOC-124225  ศูนย์ข้อมูลกลางทางวัฒนธรรม  http://123.242.145.13/album/124225
#
#                                                title  \
# 0                                              สะตวง
# 1                               อนุสาวรีย์หลวงปู่ทวด
# 2  การทำบุญสลาภัตวัดขุนคง                        ...
# 3                                         วัดหลังถ้ำ
# 4                                         วัดหลังถ้ำ
#
#                                          description    tambon    amphoe  \
# 0  &lt;p&gt;\n\t &lt;/p&gt;\n&lt;p style=&quot;te...  เมืองงาย  เชียงดาว
# 1  &lt;p&gt;\n\tอนุสาวรีย์หลวงปู่ทวด วัดป่าธาราภิ...   ปิงโค้ง  เชียงดาว
# 2  &lt;p&gt;\n\tประเพณีการทำบุญสลากภัตวัดขุนคง หม...     ขุนคง     หางดง
# 3  &lt;p&gt;\n\t &lt;/p&gt;\n&lt;p&gt;\n\tสังกัดค...    สองแคว   ดอยหล่อ
# 4  &lt;p&gt;\n\t &lt;/p&gt;\n&lt;p&gt;\n\tสังกัดค...    สองแคว   ดอยหล่อ
#
#     province             category      lat      lon
# 0  เชียงใหม่   ประเพณีและพิธีกรรม  19.4648  98.9649
# 1  เชียงใหม่            ศิลปวัตถุ  19.4819  99.0098
# 2  เชียงใหม่   ประเพณีและพิธีกรรม  18.6566  98.9628
# 3  เชียงใหม่  หน่วยงานทางวัฒนธรรม  18.5108  98.8526
# 4  เชียงใหม่             ศาสนสถาน  18.5108  98.8526
